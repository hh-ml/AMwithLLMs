# %% [markdown]
# # Finetuning GPT-3.X-FeaTxT

# %% [markdown]
# https://github.com/norahsakal/fine-tune-gpt3-model/blob/main/fine_tune_step_by_step.ipynb

# %% [markdown]
# Finetuning GPT-turbo with the **all-in-one predictions strategy**.
#
# Data files: `data_train_v3.jsonl`, `data_val_v3.jsonl`, `data_test_v3.jsonl`

# %% [markdown]
# ## Libraries

# %%
# !pip install --upgrade pip
# !pip install openai
# (choose "base" kernel)

# %%
import os
import json
import pickle
import pandas as pd
from pathlib import Path

from sklearn.metrics import classification_report

import openai
from openai import OpenAI

# %% [markdown]
# ## API key

# %%
api_key ="<your key>"
openai.api_key = api_key

# %% [markdown]
# ## Upload data to OpenAI

# %%
data_dir = os.path.join(os.getcwd(), "data")

# %%
train_file_name = os.path.join(data_dir, "data_train_v3.jsonl")
val_file_name = os.path.join(data_dir, "data_val_v3.jsonl")
test_file_name = os.path.join(data_dir, "data_test_v3.jsonl")

# %%
client = OpenAI(api_key=api_key)

# %% [markdown]
# ### Train set

# %%
train_upload_response = client.files.create(
    file = Path(train_file_name),
    purpose = "fine-tune"
)

# %%
train_upload_response
# Out:
# FileObject(id='file-guu73kQEEqLyKDrYT7bogdh2', bytes=1309172, created_at=1705237534, filename='data_train_v3.jsonl', object='file', purpose='fine-tune', status='processed', status_details=None)

# %%
train_file_id = train_upload_response.id
train_file_id
# Out:
# 'file-guu73kQEEqLyKDrYT7bogdh2'

# %% [markdown]
# ### Validation set

# %%
val_upload_response = client.files.create(
    file = Path(val_file_name),
    purpose = "fine-tune"
)

# %%
val_upload_response
# Out:
# FileObject(id='file-KezBTR34IUBHwB9DUijxnvAe', bytes=147676, created_at=1705237541, filename='data_val_v3.jsonl', object='file', purpose='fine-tune', status='processed', status_details=None)

# %%
val_file_id = val_upload_response.id
val_file_id
# Out:
# 'file-KezBTR34IUBHwB9DUijxnvAe'

# %% [markdown]
# ### Test set

# %% [raw]
# test_upload_response = client.files.create(
#     file = Path(test_file_name),
#     purpose = "fine-tune"
# )

# %% [raw]
# test_upload_response

# %% [raw]
# test_file_id = test_upload_response.id
# test_file_id

# %% [markdown]
# ## Fine-tune model

# %%
# Launch fine-tuning

finetune_response = client.fine_tuning.jobs.create(
    training_file = train_file_id,
    validation_file = val_file_id,
    model = "gpt-3.5-turbo",
    hyperparameters = {"n_epochs": 1},
    suffix = "pe_finetune_v3d"
)

# %%
print(finetune_response.id)
# Out:
# ftjob-EBORDTXBnPozUJU5LIKLF5TO

# %%
# Checking progress

finetune_events = client.fine_tuning.jobs.list_events(fine_tuning_job_id=finetune_response.id, limit=10)
finetune_events.model_dump()
# Out:
# {'data': [{'id': 'ftevent-gc2EVm1k9Yt9DnxsqaWF30iK',
#    'created_at': 1705238392,
#    'level': 'info',
#    'message': 'The job has successfully completed',
#    'object': 'fine_tuning.job.event',
#    'data': {},
#    'type': 'message'},
#   {'id': 'ftevent-0cAWhrFtopjFJVx3vu5rCqHS',
#    'created_at': 1705238389,
#    'level': 'info',
#    'message': 'New fine-tuned model created: ft:gpt-3.5-turbo-0613:personal:pe-finetune-v3d:8gugueoR',
#    'object': 'fine_tuning.job.event',
#    'data': {},
#    'type': 'message'},
#   {'id': 'ftevent-tjO8J67FrLZSX34koGimxnQC',
#    'created_at': 1705238367,
#    'level': 'info',
#    'message': 'Step 281/290: training loss=0.05, validation loss=0.10',
#    'object': 'fine_tuning.job.event',
#    'data': {'step': 281,
#     'train_loss': 0.05166623368859291,
#     'valid_loss': 0.10081902256718388,
#     'train_mean_token_accuracy': 0.9743589758872986,
#     'valid_mean_token_accuracy': 0.7407407407407407},
#    'type': 'metrics'},
#   {'id': 'ftevent-VXfEzuhvi5RUJqK0ScmN8HbG',
#    'created_at': 1705238347,
#    'level': 'info',
#    'message': 'Step 271/290: training loss=0.04, validation loss=0.06',
#    'object': 'fine_tuning.job.event',
#    'data': {'step': 271,
#     'train_loss': 0.03603921830654144,
#     'valid_loss': 0.06370711693396935,
#     'train_mean_token_accuracy': 0.9767441749572754,
#     'valid_mean_token_accuracy': 0.7384615384615385},
#    'type': 'metrics'},
#   {'id': 'ftevent-MLWE7oG4ivi8olYliN9Sy2If',
#    'created_at': 1705238329,
#    'level': 'info',
#    'message': 'Step 261/290: training loss=0.11, validation loss=0.09',
#    'object': 'fine_tuning.job.event',
#    'data': {'step': 261,
#     'train_loss': 0.10989034920930862,
#     'valid_loss': 0.09098057036704206,
#     'train_mean_token_accuracy': 0.9615384340286255,
#     'valid_mean_token_accuracy': 0.7127659574468085},
#    'type': 'metrics'},
#   {'id': 'ftevent-AkxjzT1g5BjjHrRsJKCM6fgB',
#    'created_at': 1705238311,
#    'level': 'info',
#    'message': 'Step 251/290: training loss=0.10, validation loss=0.01',
#    'object': 'fine_tuning.job.event',
#    'data': {'step': 251,
#     'train_loss': 0.1024165153503418,
#     'valid_loss': 0.011788495381673177,
#     'train_mean_token_accuracy': 0.96875,
#     'valid_mean_token_accuracy': 0.75},
#    'type': 'metrics'},
#   {'id': 'ftevent-db1ELi0P8HoWtanWYAjXmkec',
#    'created_at': 1705238291,
#    'level': 'info',
#    'message': 'Step 241/290: training loss=0.03, validation loss=0.10',
#    'object': 'fine_tuning.job.event',
#    'data': {'step': 241,
#     'train_loss': 0.03294012323021889,
#     'valid_loss': 0.09967570304870606,
#     'train_mean_token_accuracy': 0.9722222089767456,
#     'valid_mean_token_accuracy': 0.7},
#    'type': 'metrics'},
#   {'id': 'ftevent-iK1NdlJpzVWSCwkrzURkbHTN',
#    'created_at': 1705238273,
#    'level': 'info',
#    'message': 'Step 231/290: training loss=0.13, validation loss=0.07',
#    'object': 'fine_tuning.job.event',
#    'data': {'step': 231,
#     'train_loss': 0.12858667969703674,
#     'valid_loss': 0.07010362503376413,
#     'train_mean_token_accuracy': 0.9433962106704712,
#     'valid_mean_token_accuracy': 0.7446808510638298},
#    'type': 'metrics'},
#   {'id': 'ftevent-U01vI3ijMk1CKg9QuFFNJvAm',
#    'created_at': 1705238252,
#    'level': 'info',
#    'message': 'Step 221/290: training loss=0.17, validation loss=0.13',
#    'object': 'fine_tuning.job.event',
#    'data': {'step': 221,
#     'train_loss': 0.17235848307609558,
#     'valid_loss': 0.12760051604240172,
#     'train_mean_token_accuracy': 0.9666666388511658,
#     'valid_mean_token_accuracy': 0.7419354838709677},
#    'type': 'metrics'},
#   {'id': 'ftevent-aio3Iksltn3DtmDrP2Ne2xsx',
#    'created_at': 1705238232,
#    'level': 'info',
#    'message': 'Step 211/290: training loss=0.07, validation loss=0.16',
#    'object': 'fine_tuning.job.event',
#    'data': {'step': 211,
#     'train_loss': 0.06756413727998734,
#     'valid_loss': 0.16314075469970704,
#     'train_mean_token_accuracy': 0.9661017060279846,
#     'valid_mean_token_accuracy': 0.74},
#    'type': 'metrics'}],
#  'object': 'list',
#  'has_more': True}

# %%
retrieve_response = client.fine_tuning.jobs.retrieve(finetune_response.id)
retrieve_response.model_dump()
# Out:
# {'id': 'ftjob-EBORDTXBnPozUJU5LIKLF5TO',
#  'created_at': 1705237553,
#  'error': None,
#  'fine_tuned_model': 'ft:gpt-3.5-turbo-0613:personal:pe-finetune-v3d:8gugueoR',
#  'finished_at': 1705238387,
#  'hyperparameters': {'n_epochs': 1,
#   'batch_size': 1,
#   'learning_rate_multiplier': 2},
#  'model': 'gpt-3.5-turbo-0613',
#  'object': 'fine_tuning.job',
#  'organization_id': 'org-ao865HLfwm7KSarTu10iG90O',
#  'result_files': ['file-0w7xgbRJvAWLT0Y3LLKX5Eby'],
#  'status': 'succeeded',
#  'trained_tokens': 260386,
#  'training_file': 'file-guu73kQEEqLyKDrYT7bogdh2',
#  'validation_file': 'file-KezBTR34IUBHwB9DUijxnvAe'}

# %% [markdown]
# ## Save fine-tuned model

# %%
# Option 3

if retrieve_response.fine_tuned_model == None:
    
    finetuned_model = client.fine_tuning.jobs.retrieve("<JOB ID from API>").fine_tuned_model

else:
    
    finetuned_model = retrieve_response.model_dump()["fine_tuned_model"]

# %%
finetuned_model
# Out:
# 'ft:gpt-3.5-turbo-0613:personal:pe-finetune-v3d:8gugueoR'

# %% [markdown]
# ## Evaluate on test set

# %%
# Evaluate the whole test set

predictions_l = []

with open(os.path.join(data_dir, "data_test_v3.jsonl"), 'r') as fh:
    
    lines_l = [json.loads(line) for line in fh]
    
    for i, line in enumerate(lines_l):
        
        if i%10 == 0:
            print(f"{i} samples processed")
        
        messages = line["messages"]
        
        response = client.chat.completions.create(
        model=finetuned_model,
        messages=messages
        )

        predictions_l.append(response.choices[0].message.content)
# Out:
# 0 samples processed
# 10 samples processed
# 20 samples processed
# 30 samples processed
# 40 samples processed
# 50 samples processed
# 60 samples processed
# 70 samples processed

# %%
len(predictions_l)
# Out:
# 80

# %%
# predictions_l[0].strip("][").split(", ")#[0][1:-1]

# %%
def str2list(l):
    
    results_l = []
    
    for preds in l:
        
        tmp = preds.strip("][").split(", ")                
        tmp = [x[1:-1] for x in tmp]

        results_l.append(tmp)
    
    return results_l

# %%
predictions_l_final = str2list(predictions_l)
len(predictions_l_final)
# Out:
# 80

# %%
predictions_l_final
# Out:
# [['premise',
#   'premise',
#   'major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'claim',
#   'major claim',
#   'claim',
#   'claim',
#   'premise'],
#  ['major claim',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim',
#   'claim'],
#  ['major claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'major claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'major claim',
#   'claim',
#   'claim'],
#  ['major claim',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'major claim',
#   'claim',
#   'claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'major claim',
#   'claim',
#   'claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'major claim',
#   'claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'major claim',
#   'claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'major claim'],
#  ['major claim',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'major claim',
#   'claim',
#   'premise',
#   'premise',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'major claim',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'major claim',
#   'claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'major claim',
#   'claim'],
#  ['claim',
#   'major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'major claim'],
#  ['major claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim',
#   'claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'premise',
#   'claim',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'major claim',
#   'claim',
#   'claim'],
#  ['major claim',
#   'premise',
#   'premise',
#   'major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim',
#   'claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['claim',
#   'major claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'major claim',
#   'claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'major claim',
#   'claim',
#   'premise'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'major claim'],
#  ['claim',
#   'major claim',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'major claim',
#   'claim',
#   'claim'],
#  ['claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'major claim',
#   'claim',
#   'claim'],
#  ['claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'major claim',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'major claim'],
#  ['major claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'major claim'],
#  ['major claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'major claim',
#   'claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'major claim',
#   'claim',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'major claim',
#   'claim'],
#  ['claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'major claim',
#   'claim'],
#  ['major claim',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'major claim',
#   'claim'],
#  ['major claim',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim',
#   'claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'major claim',
#   'claim'],
#  ['major claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'major claim',
#   'claim'],
#  ['major claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'major claim'],
#  ['claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'claim',
#   'major claim'],
#  ['claim',
#   'major claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'claim',
#   'major claim'],
#  ['claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'major claim'],
#  ['major claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'major claim'],
#  ['claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise'],
#  ['claim',
#   'major claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'claim',
#   'premise',
#   'major claim',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'major claim',
#   'claim'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'premise'],
#  ['major claim',
#   'claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['claim',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'premise',
#   'claim',
#   'major claim'],
#  ['premise',
#   'claim',
#   'premise',
#   'claim',
#   'premise',
#   'premise',
#   'claim',
#   'major claim']]

# %%
with open(os.path.join(data_dir, 'predictions_l_v3.pkl'), 'wb') as f:
    
    pickle.dump(predictions_l_final, f)

# %% [raw]
# with open(os.path.join(data_dir, 'predictions_l_v2.pkl'), 'rb') as f:
#
#     predictions_l2 = pickle.load(f)

# %% [raw]
# predictions_l == predictions_l2

# %% [markdown]
# ## Results

# %%
df = pd.read_csv(os.path.join(data_dir, "persuasive_essays_dataset.csv"), index_col=0)

# %%
test_df = df[df.split == 'TEST']
# test_df

# %%
essay_files_l = list(df[df.split=="TEST"].essay_file.value_counts().index)
len(essay_files_l)
# Out:
# 80

# %%
grounds_l = []

for essay in essay_files_l:
    
    sub_df = test_df[test_df.essay_file==essay]
    labels = list(sub_df.label.values)
    
    grounds_l.append(labels)

    
def rename_labels(l):
    
    l = list(map(lambda x: x.replace("MajorClaim", "major claim"), l))
    l = list(map(lambda x: x.replace("Claim", "claim"), l))
    l = list(map(lambda x: x.replace("Premise", "premise"), l))
    
    return l

for i, labels in enumerate(grounds_l):
    
    grounds_l[i] = rename_labels(labels)

# %%
counter = 1

for l1, l2 in zip(predictions_l_final, grounds_l):
    
    if len(l1) != len(l2):
        print(f"Essay no {counter}:", f"nb of pred: {len(l1)}", f"/ nb of labels: {len(l2)}")
    
    counter += 1
# Out:
# Essay no 6: nb of pred: 23 / nb of pred: 22

# %% [markdown]
# - Only for essay #6, the model predicts 23 labels for 22 components. We remove the last prediction for matching purposes.
# - For the rest, the number of predictions matches the number of labels.

# %%
predictions_l_final[5] = predictions_l_final[5][:-1]

for l1, l2 in zip(predictions_l_final, grounds_l):
    
    if len(l1) != len(l2):
        print(f"Essay no {counter}:", f"nb of pred: {len(l1)}", f"/ nb of pred: {len(l2)}")
    
    counter += 1

# %%
def flatten_list(ll):
    return [item for l in ll for item in l]

grounds_l_final = flatten_list(grounds_l)
predictions_l_final_v2 = flatten_list(predictions_l_final)

len(grounds_l_final), len(predictions_l_final_v2)
# Out:
# (1266, 1266)

# %%
print(classification_report(grounds_l_final, predictions_l_final_v2, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#        claim      0.677     0.691     0.684       304
#  major claim      0.922     0.922     0.922       153
#      premise      0.894     0.888     0.891       809
#
#     accuracy                          0.844      1266
#    macro avg      0.831     0.833     0.832      1266
# weighted avg      0.845     0.844     0.845      1266

# %% [markdown]
# ```
# Results for 1 epoch
#
#               precision    recall  f1-score   support
#
#        claim      0.677     0.691     0.684       304
#  major claim      0.922     0.922     0.922       153
#      premise      0.894     0.888     0.891       809
#
#     accuracy                          0.844      1266
#    macro avg      0.831     0.833     0.832      1266
# weighted avg      0.845     0.844     0.845      1266
# ```
